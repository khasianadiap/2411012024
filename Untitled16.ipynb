# %%
nama = 'Khashia'
usia = 20
gadis = True

print(type(nama))
print(type(usia))
print(type(gadis))

usia = input('Masukkan usia anda: ')
print(type(usia))

a = 10 / 2
print(type(a))

b = 1 / 2
print(type(b))

panjang = input('Masukkan panjang: ')
lebar = input('Masukkan lebar:')

print('Luas =', panjang * lebar)

nama = 'Khasia'
TabError
print(nama + ' Lahir di tahun ' + str(tahun_lahir))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# Masukkan usia anda: 20
# <class 'str'>
# <class 'float'>
# <class 'float'>
# Masukkan panjang: 18
# Masukkan lebar:5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4207/3124364950.py in <cell line: 0>()
#      19 lebar = input('Masukkan lebar:')
#      20
# ---> 21 print('Luas =', panjang * lebar)
#      22
#      23 nama = 'Khasia'
#
# TypeError: can't multiply sequence by non-int of type 'str'
